# %%
import pcbnew

# %%
board = pcbnew.LoadBoard("/home/why/projects/OrangeCrab/hardware/orangecrab_r0.1/OrangeCrab.kicad_pcb")

# %%
help(board)
# Out:
# Help on BOARD in module pcbnew object:
#
# class BOARD(BOARD_ITEM_CONTAINER)
#  |  Proxy of C++ BOARD class.
#  |
#  |  Method resolution order:
#  |      BOARD
#  |      BOARD_ITEM_CONTAINER
#  |      BOARD_ITEM
#  |      EDA_ITEM
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  AddArea(self, aNewZonesList, aNetcode, aLayer, aStartPointPosition, aHatch)
#  |      AddArea(BOARD self, PICKED_ITEMS_LIST * aNewZonesList, int aNetcode, PCB_LAYER_ID aLayer, wxPoint aStartPointPosition, int aHatch) -> ZONE_CONTAINER
#  |
#  |  AddNative(self, aItem, aMode=0)
#  |      AddNative(BOARD self, BOARD_ITEM aItem, ADD_MODE aMode=ADD_INSERT)
#  |      AddNative(BOARD self, BOARD_ITEM aItem)
#  |
#  |  AllConnectedItems(self)
#  |      AllConnectedItems(BOARD self) -> std::vector< BOARD_CONNECTED_ITEM *,std::allocator< BOARD_CONNECTED_ITEM * > > const
#  |
#  |  BuildConnectivity(self)
#  |      BuildConnectivity(BOARD self)
#  |
#  |  BuildListOfNets(self)
# ...

# %%
board.BuildListOfNets()

# %%
board.GetModules()
# Out:
# <pcbnew.MODULE_List; proxy of <Swig Object of type 'DLIST< MODULE > *' at 0x7fb97ead7a20> >

# %% [markdown]
# https://docs.kicad-pcb.org/doxygen-python/classpcbnew_1_1MODULE.html

# %%
k = map(lambda x: x.name, board.GetModules())

# %% [markdown]
# https://docs.kicad-pcb.org/doxygen/classBOARD.html

# %%
board.GetNetInfo()
# Out:
# <pcbnew.NETINFO_LIST; proxy of <Swig Object of type 'NETINFO_LIST *' at 0x7fb97d03cdb0> >

# %%
nets = board.GetNetInfo().NetsByName()

# %%
cas_net = nets['RAM_CAS#']

# %%
help(cas_net)
# Out:
# Help on NETINFO_ITEM in module pcbnew object:
#
# class NETINFO_ITEM(BOARD_ITEM)
#  |  NETINFO_ITEM(*args)
#  |
#  |  Proxy of C++ NETINFO_ITEM class.
#  |
#  |  Method resolution order:
#  |      NETINFO_ITEM
#  |      BOARD_ITEM
#  |      EDA_ITEM
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  Clear(self)
#  |      Clear(NETINFO_ITEM self)
#  |
#  |  Draw(self, panel, DC, aDrawMode, offset)
#  |      Draw(NETINFO_ITEM self, EDA_DRAW_PANEL * panel, wxDC * DC, GR_DRAWMODE aDrawMode, wxPoint offset)
#  |
#  |  GetClass(self)
#  |      GetClass(NETINFO_ITEM self) -> wxString
#  |
#  |  GetClassName(self)
#  |      GetClassName(NETINFO_ITEM self) -> wxString
#  |
#  |  GetClearance(self, aBoardItem)
#  |      GetClearance(NETINFO_ITEM self, BOARD_ITEM aBoardItem) -> int
#  |
#  |  GetMicroViaDrillSize(self)
#  |      GetMicroViaDrillSize(NETINFO_ITEM self) -> int
#  |
#  |  GetMicroViaSize(self)
#  |      GetMicroViaSize(NETINFO_ITEM self) -> int
#  |
# ...
